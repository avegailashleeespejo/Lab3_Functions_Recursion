# %%
# [CELL 1] STUDENT CONFIGURATION
LAST_NAME = "ESPEJO"
STUDENT_ID = "TUPM-26-1129"

SEED_DIGIT = int(STUDENT_ID[-1])
ID_SUM = sum(int(d) for d in STUDENT_ID if d.isdigit())
NAME_LENGTH = len(LAST_NAME)

print("Student:", LAST_NAME)
print("Seed Digit:", SEED_DIGIT)
print("Digit Sum:", ID_SUM)
print("Surname Length:", NAME_LENGTH)
# Out:
# Student: ESPEJO
# Seed Digit: 9
# Digit Sum: 21
# Surname Length: 6

# %%
# [CELL 2] FUNCTIONAL ENCAPSULATION

def greet():
    print("=" * 40)
    print(f"System Initialized for: {LAST_NAME}")
    print("=" * 40)

def identity_code():
    code = SEED_DIGIT * NAME_LENGTH
    return code
greet()
print("Identity Code:", identity_code())
# Out:
# ========================================
# System Initialized for: ESPEJO
# ========================================
# Identity Code: 54

# %%
# [CELL 4] PARAMETER PROCESSING

def user_summary(tittle, *scores, **info):
    print(f"== {tittle} ===")

    total = sum(scores)
    average = total / len(scores)

    print("Scores:", scores)
    print("Total:", total)
    print("Average:", round(average,2))

    for k,v in info.items():
        print(f"{k}: {v}")

        return average

avg = user_summary(
    f"{LAST_NAME} Academic Report",
    SEED_DIGIT * 10,
    ID_SUM % 100,
    NAME_LENGTH * 5,
    id=STUDENT_ID,
    surname=LAST_NAME
)
# Out:
# == ESPEJO Academic Report ===
# Scores: (90, 21, 30)
# Total: 141
# Average: 47.0
# id: TUPM-26-1129

# %%
# [CELL 5] RETURN MECHANISM

def compute_area(radius):
    return 3.1416 * radius **2

area = compute_area(SEED_DIGIT + 2)
print("Computed Area:", round(area,2))
# Out:
# Computed Area: 380.13

# %%
# [CELL 6] SAFE CALCULATOR

def safe_calculator(x, y):
    try:
        result = x / y
    except ZeroDivisionError:
        result = "UNDEFINED"
    return result

print("Calculator Result:", safe_calculator(ID_SUM, SEED_DIGIT))
# Out:
# Calculator Result: 2.3333333333333335

# %%
# [CELL 7] RECURSION

def factorial(n):
    if n <= 1:
        return 1
    return n * factorial(n-1)

print("Factorial Result:", factorial(SEED_DIGIT))
# Out:
# Factorial Result: 362880

# %%
# [CELL 8] STRING RECURSION

def reverse(text):
    if len(text) <= 1:
        return text
    return text[-1] + reverse(text[:-1])

print("Reverse Surname:", reverse(LAST_NAME.upper()))
# Out:
# Reverse Surname: OJEPSE

# %%
# [CELL 9] DECORATOR

def logger(func):
    def wrapper(*args, **kwargs):
        print("Executing:", func.__name__)
        return func(*args, **kwargs)
    return wrapper

@logger
def multiply(x, y):
    return x * y

print("Multiplication:", multiply(SEED_DIGIT, NAME_LENGTH))
# Out:
# Executing: multiply
# Multiplication: 54

# %%
# [CELL 10] LAMBDA
data = list(range(1, SEED_DIGIT + 10))
squared = list(map(lambda x: x**2, data))

print("Squared Data:", squared)
# Out:
# Squared Data: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324]

# %%
# [cell 11] GENERATOR

def even_squares(limit):
    for i in range(limit):
        if i % 2 == 0:
            yield i**2

for value in even_squares(NAME_LENGTH + SEED_DIGIT):
    print(value)
# Out:
# 0
# 4
# 16
# 36
# 64
# 100
# 144
# 196
